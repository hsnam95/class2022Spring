# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/class2022Spring/blob/main/import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
n = np.random.randn(100)

# %%
import matplotlib
matplotlib.pyplot.hist(n)
# Out:
# (array([ 3.,  4.,  9., 11., 26., 19., 16., 10.,  1.,  1.]),
#  array([-2.51307585, -1.99199295, -1.47091005, -0.94982715, -0.42874425,
#          0.09233865,  0.61342155,  1.13450445,  1.65558734,  2.17667024,
#          2.69775314]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot
matplotlib.pyplot.hist(n)
# Out:
# (array([ 4.,  4.,  4.,  8., 19., 21., 16., 13.,  6.,  5.]),
#  array([-2.54804234, -2.0585933 , -1.56914426, -1.07969522, -0.59024618,
#         -0.10079714,  0.3886519 ,  0.87810094,  1.36754998,  1.85699902,
#          2.34644806]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt
plt.hist(n)
# Out:
# (array([ 4.,  4.,  4.,  8., 19., 21., 16., 13.,  6.,  5.]),
#  array([-2.54804234, -2.0585933 , -1.56914426, -1.07969522, -0.59024618,
#         -0.10079714,  0.3886519 ,  0.87810094,  1.36754998,  1.85699902,
#          2.34644806]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## from import를 쓰면 import as처럼 축약해서 부를 수 있는 효과

# %%
from matplotlib import pyplot
pyplot.hist(n)
# Out:
# (array([ 3.,  4.,  9., 11., 26., 19., 16., 10.,  1.,  1.]),
#  array([-2.51307585, -1.99199295, -1.47091005, -0.94982715, -0.42874425,
#          0.09233865,  0.61342155,  1.13450445,  1.65558734,  2.17667024,
#          2.69775314]),
#  <a list of 10 Patch objects>)

# %%
from matplotlib.pyplot import hist
hist(n)
# Out:
# (array([ 3.,  4.,  9., 11., 26., 19., 16., 10.,  1.,  1.]),
#  array([-2.51307585, -1.99199295, -1.47091005, -0.94982715, -0.42874425,
#          0.09233865,  0.61342155,  1.13450445,  1.65558734,  2.17667024,
#          2.69775314]),
#  <a list of 10 Patch objects>)

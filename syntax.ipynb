# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/class2022Spring/blob/main/syntax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = [1, 2, 3, 4]
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
a = [1, 2, 3, 4]
for i in range(len(a)):
    print(a[i])
# Out:
# 1
# 2
# 3
# 4

# %%
a = ['red', 'green', 'blue', 'purple']
for i in a:
    print(i)
# Out:
# red
# green
# blue
# purple

# %%
a = ['red', 'green', 'blue', 'purple']
for i in range(len(a)):
    print(a[i])
# Out:
# red
# green
# blue
# purple

# %%
a = 0
if a == 0:
    print(a)
else:
    print(a+1)
# Out:
# 0

# %%
for i in range(1, 3):
    for j in range(3, 5):
        print(i*j)
# Out:
# 3
# 4
# 6
# 8

# %%
for i in range(1, 3):
    for j in range(3, 5):
        if j >=4:
            print(i*j)
# Out:
# 4
# 8

# %%
a = [1, 2, 3, 4]
b = [i for i in a if i >=2]
b
# Out:
# [2, 3, 4]

# %%
a = ['red', 'green', 'blue', 'purple']
b = [i for i in a if len(i) >=4]
b
# Out:
# ['green', 'blue', 'purple']

# %%
a = ['red', 'green', 'blue', 'purple']
b = [1, 2, 3, 4]
c = {a[i]:b[i] for i in range(4)}
c
# Out:
# {'blue': 3, 'green': 2, 'purple': 4, 'red': 1}

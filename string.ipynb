# %% [markdown]
# <a href="https://colab.research.google.com/github/hsnam95/class2022Spring/blob/main/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = 'abcdef'
print(s[0], s[5], s[-1], s[-6])
print(s[1:3], s[1:], s[:3], s[:])
# Out:
# <class 'str'>
# a f f a
# bc bcdef abc abcdef

# %%
n = [100, 200, 300]
print(n[0], n[2], n[-1], n[-3])
print(n[1:2], n[1:], n[:2], n[:])
# Out:
# 100 300 300 100
# [200] [200, 300] [100, 200] [100, 200, 300]

# %%
len(s)
# Out:
# 6

# %%
s[1]+s[3]+s[4:]*10
# Out:
# 'bdefefefefefefefefefef'

# %%
s.upper()
# Out:
# 'ABCDEF'

# %%
s = ' this is a house built this year.\n' 	
s
# Out:
# ' this is a house built this year.\n'

# %%
result = s.find('house') 	    # index of first instance of string t inside s (-1 if not found)
result
# Out:
# 11

# %%
result = s.find('this')	      # index of first instance of string t inside s (-1 if not found)
result
# Out:
# 1

# %%
s = s.strip()      	          # a copy of s without leading or trailing whitespace
s
# Out:
# 'this is a house built this year.'

# %%
tokens = s.split(' ')	        # split s into a list wherever a t is found (whitespace by default)
tokens
# Out:
# ['this', 'is', 'a', 'house', 'built', 'this', 'year.']

# %%
s = ' '.join(tokens)	        # combine the words of the text into a string using s as the glue
s
# Out:
# 'this is a house built this year.'

# %%
s = s.replace('this', 'that') # replace instances of t with u inside s
s
# Out:
# 'that is a house built that year.'
